# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.8.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.4
# attrs                     24.3.0
# avro                      1.12.0
# babel                     2.16.0
# beautifulsoup4            4.12.3
# bleach                    6.2.0
# build                     1.2.2.post1
# certifi                   2024.12.14
# cffi                      1.17.1
# charset-normalizer        3.4.1
# click                     8.1.8
# colorama                  0.4.6
# comm                      0.2.2
# configparser              7.1.0
# confluent-kafka           2.7.0
# debugpy                   1.8.11
# decorator                 5.1.1
# defusedxml                0.7.1
# executing                 2.1.0
# Faker                     33.3.0
# fastavro                  1.10.0
# ...
